# %% [markdown]
#  Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# Step 2. Create the DataFrame that should look like the one below.

# %%
df = {
    'fist_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', "jacobson", 'Ali', 'Milner', 'Cooze'],
    'age' : [42,52,36,24,73],
    'female': [10,1,1,0,1],
    "preTestScore": [4,24,31,2,3],
    'postTestScore': [25,94,57,62,70]
}
df = pd.DataFrame(df)
print(df)
# Out:
#   fist_name last_name  age  female  preTestScore  postTestScore
# 0     Jason    Miller   42      10             4             25
# 1     Molly  jacobson   52       1            24             94
# 2      Tina       Ali   36       1            31             57
# 3      Jake    Milner   24       0             2             62
# 4       Amy     Cooze   73       1             3             70

# %% [markdown]
# Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# Hint: Don't forget to place the labels
#
# ```

# %%
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['age']*10)
plt.xlabel('Pre-test score')
plt.ylabel('Post-test score')
plt.title('Scatter plot of pre-test and post-test scores')
plt.show()

# %% [markdown]
# Step 4. Create a Scatterplot of preTestScore and postTestScore.
# This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['postTestScore']*4.5, c=df['female'])
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('Scatterplot of preTestScore vs postTestScore')
plt.show()
